# %%
# data_2016_asbuilt_impaired_scen3:
# Seems to be slow to fill the lagoon.

# %%
from stompy.grid import unstructured_grid, multi_ugrid
import numpy as np
import pandas as pd
import os
import xarray as xr
import stompy.model.delft.dflow_model as dfm
import stompy.model.delft.io as dio
import glob

import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
run_dirs=[
    'data_2016_2d_asbuilt_impaired',
    'data_2016_2d_asbuilt_impaired_scen1-v001',
    'data_2016_2d_asbuilt_impaired_scen3-v001'
]

# %%
models=[ dfm.DFlowModel.load(run_dir)
        for run_dir in run_dirs]

# %%
for model in models:
    model.map_dataset()
# Out:
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:Regenerating edges
# INFO:UnstructuredGrid:Removing orphaned nodes
# INFO:UnstructuredGrid:0 nodes found to be orphans
# INFO:UnstructuredGrid:Removing duplicate nodes
# INFO:UnstructuredGrid:Renumbering nodes
# INFO:UnstructuredGrid:Renumbering edges
# INFO:UnstructuredGrid:Extracting grid boundary
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_x_bnd to avoid max_sides issues
# WARNING:multi_ugrid:Dropping extra cell field mesh2d_face_y_bnd to avoid max_sides issues
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)
# INFO:UnstructuredGrid:max_sides is okay (4)

# %%
fig,ax=plt.subplots()
ax.set_adjustable('datalim')

scal=map_ds['mesh2d_s1'].isel(time=40)
#scal=map_ds['mesh2d_s1'].isel(time=40).values - map_ds['mesh2d_s1'].isel(time=39).values

ccoll=g.plot_cells(values=scal,
            cmap='turbo')
plt.colorbar(ccoll)
ax.axis('off')

ccoll.set_clim([1.9,3.0])
#ccoll.set_clim([0.0,0.01])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig,axs=plt.subplots(1,3,figsize=(9,8))
plt.setp(axs,adjustable='datalim')

for model,ax in zip(models,axs):
    ds=model.map_dataset()
    scal=ds['mesh2d_s1'].isel(time=40)
    ccoll=ds.grid.plot_cells(values=scal,
                             cmap='turbo',ax=ax)
    plt.colorbar(ccoll,ax=ax)
    ax.axis('off')

    ccoll.set_clim([1.9,3.0])
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
fig,ax=plt.subplots()

ax.set_adjustable('datalim')
ccoll=g.plot_cells(values=map_ds['mesh2d_ucmag'].isel(time=-1),
            cmap='turbo')
plt.colorbar(ccoll)
ax.axis('off')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (551962.2152746613, 554066.6495507507, 4122750.3243895927, 4125365.499854582)

# %%
ccoll.set_clim([0,2])

# %%
from matplotlib import colors
fig,ax=plt.subplots()

ax.set_adjustable('datalim')
ccoll=g.plot_cells(values=map_ds['mesh2d_Numlimdt'].isel(time=-1).values.clip(1),
                   cmap='turbo',norm=colors.LogNorm(vmin=1))
plt.colorbar(ccoll)
ax.axis('off')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (551962.2152746613, 554066.6495507507, 4122750.3243895927, 4125365.499854582)

# %%
his_ds.close()

# %%
his_ds
# Out:
# <xarray.Dataset>
# Dimensions:                                       (cross_section: 10, gategens: 2, general_structures: 3, nFlowElemContourPts: 4, nFlowElemWithBnd: 2993, nFlowLink: 4536, nFlowLinkPts: 2, nNetLink: 4687, nNetLinkPts: 2, source_sink: 2, source_sink_geom_nNodes: 4, source_sink_pts: 3, station_geom_nNodes: 145, stations: 145, time: 30552, weirgens: 1, weirs: 1)
# Coordinates:
#     station_x_coordinate                          (stations) float64 ...
#     station_y_coordinate                          (stations) float64 ...
#     station_name                                  (stations) |S256 b'pch_up                                                                                                                                                                                                                                                          ' ... b'seepageB                                                                                                                                                                                                                                                        '
#     cross_section_name                            (cross_section) |S256 b'mouth_xs                                                                                                                                                                                                                                                        ' ... b'butano_mid_xs                                                                                                                                                                                                                                                   '
#     source_sink_name                              (source_sink) |S256 ...
#     general_structure_id                          (general_structures) |S256 b'pch_gate                                                                                                                                                                                                                                                        ' ... b'mouth_B                                                                                                                                                                                                                                                         '
#     gategen_name                                  (gategens) |S256 b'nmc_gate                                                                                                                                                                                                                                                        ' b'nm_ditch_gate                                                                                                                                                                                                                                                   '
#     weirgen_id                                    (weirgens) |S256 b'butano_weir                                                                                                                                                                                                                                                     '
#   * time                                          (time) datetime64[ns] 2013-03-22T12:00:00 ... 2014-02-03T17:45:00
#   * cross_section                                 (cross_section) <U15 'mouth_xs' ... 'butano_mid_xs'
#   * stations                                      (stations) <U18 'pch_up' ... 'seepageB'
#   * weirs                                         (weirs) <U11 'butano_weir'
#   * general_structures                            (general_structures) <U8 'pch_gate' ... 'mouth_B'
#   * gategens                                      (gategens) <U13 'nmc_gate' 'nm_ditch_gate'
# Dimensions without coordinates: nFlowElemContourPts, nFlowElemWithBnd, nFlowLink, nFlowLinkPts, nNetLink, nNetLinkPts, source_sink, source_sink_geom_nNodes, source_sink_pts, station_geom_nNodes, weirgens
# Data variables:
#     FlowElem_xcc                                  (nFlowElemWithBnd) float64 ...
#     FlowElem_ycc                                  (nFlowElemWithBnd) float64 ...
#     FlowElem_zcc                                  (nFlowElemWithBnd) float64 ...
#     FlowElem_bac                                  (nFlowElemWithBnd) float64 ...
#     FlowElem_xzw                                  (nFlowElemWithBnd) float64 ...
#     FlowElem_yzw                                  (nFlowElemWithBnd) float64 ...
#     FlowElemContour_x                             (nFlowElemWithBnd, nFlowElemContourPts) float64 ...
#     FlowElemContour_y                             (nFlowElemWithBnd, nFlowElemContourPts) float64 ...
#     FlowElem_bl                                   (nFlowElemWithBnd) float64 ...
#     ElemLink                                      (nNetLink, nNetLinkPts) int32 ...
#     FlowLink                                      (nFlowLink, nFlowLinkPts) int32 ...
#     FlowLinkType                                  (nFlowLink) int32 ...
#     FlowLink_xu                                   (nFlowLink) float64 ...
#     FlowLink_yu                                   (nFlowLink) float64 ...
#     projected_coordinate_system                   int32 ...
#     FlowLink_lonu                                 (nFlowLink) float64 ...
#     FlowLink_latu                                 (nFlowLink) float64 ...
#     FlowElemDomain                                (nFlowElemWithBnd) int32 ...
#     FlowLinkDomain                                (nFlowLink) int32 ...
#     FlowElemGlobalNr                              (nFlowElemWithBnd) int32 ...
#     station_id                                    (stations) |S256 ...
#     station_geom                                  int32 ...
#     station_geom_node_count                       (stations) int32 ...
#     station_geom_node_coordx                      (station_geom_nNodes) float64 ...
#     station_geom_node_coordy                      (station_geom_nNodes) float64 ...
#     waterlevel                                    (time, stations) float64 ...
#     bedlevel                                      (stations) float64 ...
#     x_velocity                                    (time, stations) float64 ...
#     y_velocity                                    (time, stations) float64 ...
#     velocity_magnitude                            (time, stations) float64 ...
#     discharge_magnitude                           (time, stations) float64 ...
#     taus                                          (time, stations) float64 ...
#     windx                                         (time, stations) float64 ...
#     windy                                         (time, stations) float64 ...
#     rain                                          (time, stations) float64 ...
#     cross_section_geom                            int32 ...
#     cross_section_geom_node_count                 (cross_section) int32 ...
#     cross_section_discharge                       (time, cross_section) float64 ...
#     cross_section_cumulative_discharge            (time, cross_section) float64 ...
#     cross_section_area                            (time, cross_section) float64 ...
#     cross_section_velocity                        (time, cross_section) float64 ...
#     source_sink_geom                              int32 ...
#     source_sink_geom_node_count                   (source_sink) int32 ...
#     source_sink_geom_node_coordx                  (source_sink_geom_nNodes) float64 ...
#     source_sink_geom_node_coordy                  (source_sink_geom_nNodes) float64 ...
#     source_sink_x_coordinate                      (source_sink_pts, source_sink) float64 ...
#     source_sink_y_coordinate                      (source_sink_pts, source_sink) float64 ...
#     source_sink_prescribed_discharge              (time, source_sink) float64 ...
#     source_sink_prescribed_salinity_increment     (time, source_sink) float64 ...
#     source_sink_prescribed_temperature_increment  (time, source_sink) float64 ...
#     source_sink_current_discharge                 (time, source_sink) float64 ...
#     source_sink_cumulative_volume                 (time, source_sink) float64 ...
#     source_sink_discharge_average                 (time, source_sink) float64 ...
#     water_balance_total_volume                    (time) float64 ...
#     water_balance_storage                         (time) float64 ...
#     water_balance_volume_error                    (time) float64 ...
#     water_balance_boundaries_in                   (time) float64 ...
#     water_balance_boundaries_out                  (time) float64 ...
#     water_balance_boundaries_total                (time) float64 ...
#     water_balance_exchange_with_1D_in             (time) float64 ...
#     water_balance_exchange_with_1D_out            (time) float64 ...
#     water_balance_exchange_with_1D_total          (time) float64 ...
#     water_balance_precipitation_total             (time) float64 ...
#     water_balance_evaporation                     (time) float64 ...
#     water_balance_source_sink                     (time) float64 ...
#     water_balance_groundwater_in                  (time) float64 ...
#     water_balance_groundwater_out                 (time) float64 ...
#     water_balance_groundwater_total               (time) float64 ...
#     water_balance_laterals_in                     (time) float64 ...
#     water_balance_laterals_out                    (time) float64 ...
#     water_balance_laterals_total                  (time) float64 ...
#     water_balance_laterals_in_1D                  (time) float64 ...
#     water_balance_laterals_out_1D                 (time) float64 ...
#     water_balance_laterals_total_1D               (time) float64 ...
#     water_balance_laterals_in_2D                  (time) float64 ...
#     water_balance_laterals_out_2D                 (time) float64 ...
#     water_balance_laterals_total_2D               (time) float64 ...
#     water_balance_Qext_in                         (time) float64 ...
#     water_balance_Qext_out                        (time) float64 ...
#     water_balance_Qext_total                      (time) float64 ...
#     water_balance_Qext_in_1D                      (time) float64 ...
#     water_balance_Qext_out_1D                     (time) float64 ...
#     water_balance_Qext_total_1D                   (time) float64 ...
#     water_balance_Qext_in_2D                      (time) float64 ...
#     water_balance_Qext_out_2D                     (time) float64 ...
#     water_balance_Qext_total_2D                   (time) float64 ...
#     water_balance_total_volume_interception       (time) float64 ...
#     water_balance_evaporation_interception        (time) float64 ...
#     water_balance_precipitation_on_ground         (time) float64 ...
#     general_structure_geom                        int32 ...
#     general_structure_geom_node_count             (general_structures) int32 ...
#     general_structure_discharge                   (time, general_structures) float64 ...
#     general_structure_crest_level                 (time, general_structures) float64 ...
#     general_structure_gate_lower_edge_level       (time, general_structures) float64 ...
#     general_structure_gate_opening_width          (time, general_structures) float64 ...
#     general_structure_s1up                        (time, general_structures) float64 ...
#     general_structure_s1dn                        (time, general_structures) float64 ...
#     general_structure_head                        (time, general_structures) float64 ...
#     general_structure_flow_area                   (time, general_structures) float64 ...
#     general_structure_velocity                    (time, general_structures) float64 ...
#     gategen_geom                                  int32 ...
#     gategen_geom_node_count                       (gategens) int32 ...
#     gategen_discharge                             (time, gategens) float64 ...
#     gategen_crest_level                           (time, gategens) float64 ...
#     gategen_crest_width                           (time, gategens) float64 ...
#     gategen_gate_lower_edge_level                 (time, gategens) float64 ...
#     gategen_flow_through_height                   (time, gategens) float64 ...
#     gategen_gate_opening_width                    (time, gategens) float64 ...
#     gategen_s1up                                  (time, gategens) float64 ...
#     gategen_s1dn                                  (time, gategens) float64 ...
#     weirgen_geom                                  int32 ...
#     weirgen_geom_node_count                       (weirgens) int32 ...
#     weirgen_discharge                             (time, weirgens) float64 ...
#     weirgen_crest_level                           (time, weirgens) float64 ...
#     weirgen_crest_width                           (time, weirgens) float64 ...
#     weirgen_s1up                                  (time, weirgens) float64 ...
#     weirgen_s1dn                                  (time, weirgens) float64 ...
#     timestep                                      (time) float64 ...
# Attributes:
#     institution:    Deltares
#     references:     http://www.deltares.nl
#     source:         Deltares, D-Flow FM Version 1.2.136.140489, Dec 13 2021, ...
#     history:        Created on 2022-03-11T15:44:08-0800, D-Flow FM
#     date_created:   2022-03-11T15:44:08-0800
#     date_modified:  2022-03-11T15:44:08-0800
#     Conventions:    CF-1.5 Deltares-0.1
#     long_name:      y-coordinate of gategen
#     units:          m
#     standard_name:  projection_y_coordinate
#     axis:           Y

# %%
his_ds=xr.open_dataset(run_dir+"/DFM_OUTPUT_flowfm/flowfm_0000_his.nc")

# %%
his_ds=model.his_dataset(decode_geometry=False)
# Out:
# Yuck - duplicate cross section names

# %%
list(his_ds)
# Out:
# ['FlowElem_xcc',
#  'FlowElem_ycc',
#  'FlowElem_zcc',
#  'FlowElem_bac',
#  'FlowElem_xzw',
#  'FlowElem_yzw',
#  'FlowElemContour_x',
#  'FlowElemContour_y',
#  'FlowElem_bl',
#  'ElemLink',
#  'FlowLink',
#  'FlowLinkType',
#  'FlowLink_xu',
#  'FlowLink_yu',
#  'projected_coordinate_system',
#  'FlowLink_lonu',
#  'FlowLink_latu',
#  'FlowElemDomain',
#  'FlowLinkDomain',
#  'FlowElemGlobalNr',
#  'station_id',
#  'station_geom',
#  'station_geom_node_count',
#  'station_geom_node_coordx',
#  'station_geom_node_coordy',
#  'waterlevel',
#  'bedlevel',
#  'x_velocity',
#  'y_velocity',
#  'velocity_magnitude',
#  'discharge_magnitude',
#  'taus',
#  'windx',
#  'windy',
#  'rain',
#  'cross_section_geom',
#  'cross_section_geom_node_count',
#  'cross_section_discharge',
#  'cross_section_cumulative_discharge',
#  'cross_section_area',
#  'cross_section_velocity',
#  'source_sink_geom',
#  'source_sink_geom_node_count',
#  'source_sink_geom_node_coordx',
#  'source_sink_geom_node_coordy',
#  'source_sink_x_coordinate',
#  'source_sink_y_coordinate',
#  'source_sink_prescribed_discharge',
#  'source_sink_prescribed_salinity_increment',
#  'source_sink_prescribed_temperature_increment',
#  'source_sink_current_discharge',
#  'source_sink_cumulative_volume',
#  'source_sink_discharge_average',
#  'water_balance_total_volume',
#  'water_balance_storage',
#  'water_balance_volume_error',
#  'water_balance_boundaries_in',
#  'water_balance_boundaries_out',
#  'water_balance_boundaries_total',
#  'water_balance_exchange_with_1D_in',
#  'water_balance_exchange_with_1D_out',
#  'water_balance_exchange_with_1D_total',
#  'water_balance_precipitation_total',
#  'water_balance_evaporation',
#  'water_balance_source_sink',
#  'water_balance_groundwater_in',
#  'water_balance_groundwater_out',
#  'water_balance_groundwater_total',
#  'water_balance_laterals_in',
#  'water_balance_laterals_out',
#  'water_balance_laterals_total',
#  'water_balance_laterals_in_1D',
#  'water_balance_laterals_out_1D',
#  'water_balance_laterals_total_1D',
#  'water_balance_laterals_in_2D',
#  'water_balance_laterals_out_2D',
#  'water_balance_laterals_total_2D',
#  'water_balance_Qext_in',
#  'water_balance_Qext_out',
#  'water_balance_Qext_total',
#  'water_balance_Qext_in_1D',
#  'water_balance_Qext_out_1D',
#  'water_balance_Qext_total_1D',
#  'water_balance_Qext_in_2D',
#  'water_balance_Qext_out_2D',
#  'water_balance_Qext_total_2D',
#  'water_balance_total_volume_interception',
#  'water_balance_evaporation_interception',
#  'water_balance_precipitation_on_ground',
#  'general_structure_geom',
#  'general_structure_geom_node_count',
#  'general_structure_discharge',
#  'general_structure_crest_level',
#  'general_structure_gate_lower_edge_level',
#  'general_structure_gate_opening_width',
#  'general_structure_s1up',
#  'general_structure_s1dn',
#  'general_structure_head',
#  'general_structure_flow_area',
#  'general_structure_velocity',
#  'gategen_geom',
#  'gategen_geom_node_count',
#  'gategen_discharge',
#  'gategen_crest_level',
#  'gategen_crest_width',
#  'gategen_gate_lower_edge_level',
#  'gategen_flow_through_height',
#  'gategen_gate_opening_width',
#  'gategen_s1up',
#  'gategen_s1dn',
#  'weirgen_geom',
#  'weirgen_geom_node_count',
#  'weirgen_discharge',
#  'weirgen_crest_level',
#  'weirgen_crest_width',
#  'weirgen_s1up',
#  'weirgen_s1dn',
#  'timestep']

# %%
his_ds.weirgens
# Out:
# <xarray.DataArray 'weirgens' (weirgens: 1)>
# array(['butano_weir'], dtype='<U11')
# Coordinates:
#     weirgen_id  (weirgens) |S256 b'butano_weir                                                                                                                                                                                                                                                     '
#   * weirgens    (weirgens) <U11 'butano_weir'

# %%
fig,axs=plt.subplots(2,1,sharex=True)

axs[0].plot(his_ds.time, his_ds.weirgen_discharge.sel(weirgens='butano_weir'))
axs[1].plot(his_ds.time, his_ds.weirgen_s1up.sel(weirgens='butano_weir'))
axs[1].plot(his_ds.time, his_ds.weirgen_s1dn.sel(weirgens='butano_weir'))
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
qcm_pre2016=pd.read_csv("../../data/ESA_QCM/ESA_draft_PescaderoQCM_output.csv",
                                    skiprows=[0],usecols=range(7),
                                    parse_dates=['Date (PST)'])
qcm=qcm_pre2016
qcm['time']=qcm['Date (PST)'] + np.timedelta64(8,'h') # Shift to UTC.

crest_tim=dio.read_dfm_tim(run_dir+'/mouth_CrestLevel.tim',ref_time=np.datetime64('2013-03-22 00:00'))
crestB_tim=dio.read_dfm_tim(run_dir+'/mouth_B_CrestLevel.tim',ref_time=np.datetime64('2013-03-22 00:00'))

ocean_tim=dio.read_dfm_tim(run_dir+'/ocean_bc_0001.tim',ref_time=np.datetime64('2013-03-22 00:00'))

# %%
fig,axs=plt.subplots(2,1,sharex=True)

#axs[0].plot(his_ds.time, his_ds.gategen_discharge.isel(gategens=0),label='pch_gate')
axs[0].plot(his_ds.time, -his_ds.cross_section_discharge.isel(cross_section=3),label='n_complex_xs')

#axs[1].plot(his_ds.time, his_ds.gategen_s1up.isel(gategens=0),label='pch_gate s1up')
#axs[1].plot(his_ds.time, his_ds.gategen_s1dn.isel(gategens=0),label='pch_gate s1dn')

axs[1].plot(his_ds.time, his_ds.waterlevel.isel(stations=0),label='pch_up')
axs[1].plot(his_ds.time, his_ds.waterlevel.isel(stations=1),label='pch_down')
axs[1].plot(his_ds.time, his_ds.waterlevel.isel(stations=7),label='nck')
axs[1].plot(his_ds.time, his_ds.waterlevel.isel(stations=10),label='pc3')
axs[1].plot(his_ds.time, his_ds.waterlevel.isel(stations=11),label='nmp')

#axs[1].plot(his_ds.time, his_ds.waterlevel.isel(stations=16),label='ocean')
#axs[1].plot(crest_tim.time, crest_tim.val1,label='Mouth crest')

#axs[0].plot(map_ds.time, np.zeros(len(map_ds.time)), 'go')

axs[1].legend(loc='lower right')
# Out:
# <img src="data:image/png;base64,..." width="703.6363483854565">

# %%
his_slr0_ds=xr.open_dataset(run_dir.replace('slr2ft','slr0ft')+"/DFM_OUTPUT_flowfm/flowfm_0000_his.nc")

# %%
# Quick comparison of slr0ft and slr2ft
fig,axs=plt.subplots(2,1,sharex=True)

for h,ls in zip([his_ds,his_slr0_ds],['-','--']):
    axs[0].plot(h.time, -h.cross_section_discharge.isel(cross_section=3),ls=ls,label='n_complex_xs')
    axs[1].plot(h.time, h.waterlevel.isel(stations=0),ls=ls,label='pch_up')
    axs[1].plot(h.time, h.waterlevel.isel(stations=1),ls=ls,label='pch_down')
    axs[1].plot(h.time, h.waterlevel.isel(stations=7),ls=ls,label='nck')
    axs[1].plot(h.time, h.waterlevel.isel(stations=10),ls=ls,label='pc3')
    axs[1].plot(h.time, h.waterlevel.isel(stations=11),ls=ls,label='nmp')

axs[1].legend(loc='lower right')
# Out:
# <img src="data:image/png;base64,..." width="928.1817980640195">

# %%
# While tidal, things look fine. But then we get some weird blips say around 6/10. the downstream
# side (s1dn and pch_down) dip. presumably due to partial breach?
# at the same time, pch_up actually jumps up.  Why? 
# I think this is a DFM bug. 
# the run does complete in v06, but this feature is weird.
# The mouth time series, ocean BC time series, water balance time series,
# all show nothing odd at this time.
# The first sign of weirdness is, simultaneously, pch_up rises, pch_gate s1up 
# falls (?), and both of the downstream water levels fall, with the downstream
# side of the gate falling more.
# there is no disturbance at the mouth
# appears that the sign convention for gate discharge is positive downstream
# The discharge time series is sort of twitchy - is that instability, or
# some forcing term like wind?
# Oddly, pch_up jumps up, while gate s1up drops
# What about other nearby stations? They react to this, but no sudden 
# jumps. points to numerical or config issues at the culverts.

# In the v14 slr2ft run, flow eventually starts going around the butano flow control
# structure at high rate, killing the timestep.
